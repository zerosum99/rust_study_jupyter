// %% [markdown]
// # 1. 덕타이핑 처리

// %% [markdown]
// ## 1-1 : 트레이트 정의 및 구조체의 구현

// %%
trait Say {
    fn say(&self) ;
}

// %%
#[derive(Debug)]
struct Parent {
    name : String, 
}

// %%
impl Say for Parent {
    fn say(&self) {
        println!(" Parent instance ={}", self.name); 
    }
}

// %%
#[derive(Debug)]
struct Child {
    name : String, 
}

// %%
impl Say for Child {
    fn say(&self) {
        println!(" Child instance ={}", self.name); 
    }
}

// %% [markdown]
// ## 1-2 : 매개변수 타입을 트레이트 구현으로 지정

// %%
fn say(ins : impl Say) {
    ins.say(); 
}

// %%
let p = Parent { name :"부모".to_string() };

// %%
let c = Child { name :"자식".to_string() };

// %%
say(p);
// Out:
//  Parent instance =부모

// %%
say(c);
// Out:
//  Child instance =자식

// %%
p
// Out:
// [E0425] Error: cannot find value `p` in this scope
//    ╭─[command_12:1:1]
//    │
//  1 │ p
//    · ┬
//    · ╰── not found in this scope
// ───╯

// %%
c
// Out:
// [E0425] Error: cannot find value `c` in this scope
//    ╭─[command_13:1:1]
//    │
//  1 │ c
//    · ┬
//    · ╰── not found in this scope
// ───╯

// %%
let p1 = Parent { name :"부모1".to_string() };
let c1 = Child { name :"자식1".to_string() };

// %%
fn say1(ins : &impl Say) {
    ins.say(); 
}

// %%
say1(&p1);
// Out:
//  Parent instance =부모1

// %%
say1(&p1);
// Out:
//  Parent instance =부모1

// %%
println!(" {:?}",p1);
// Out:
//  Parent { name: "부모1" }

// %%
println!(" {:?}",c1);
// Out:
//  Child { name: "자식1" }
